# %% [markdown]
# # Part 1: Calender Dictionary

# %%
import pandas as pd
import numpy as np

wd_list = [
            #2015
            #jan
            '2015-01-2',
    
            '2015-01-5', 
            '2015-01-6',
            '2015-01-7',
            '2015-01-8',
            '2015-01-9',
    
            '2015-01-12', 
            '2015-01-13',
            '2015-01-14',
            '2015-01-15',
            '2015-01-16',
    
            '2015-01-20', 
            '2015-01-21',
            '2015-01-22',
            '2015-01-23',
            
            '2015-01-26', 
            '2015-01-27',
            '2015-01-28',
            '2015-01-29',
            '2015-01-30',
            
            #feb
            '2015-02-2', 
            '2015-02-3',
            '2015-02-4',
            '2015-02-5',
            '2015-02-6',
            
            '2015-02-9', 
            '2015-02-10',
            '2015-02-11',
            '2015-02-13',
            
            '2015-02-16', 
            '2015-02-17',
            '2015-02-18',
            '2015-02-19',
            '2015-02-20',
    
            '2015-02-23', 
            '2015-02-24',
            '2015-02-25',
            '2015-02-26',
            '2015-02-27',
    
            #march
            '2015-03-2', 
            '2015-03-3',
            '2015-03-4',
            '2015-03-5',
            '2015-03-6',
    
            '2015-03-9', 
            '2015-03-10',
            '2015-03-11',
            '2015-03-12',
            '2015-03-13',
    
            '2015-03-16', 
            '2015-03-17',
            '2015-03-18',
            '2015-03-19',
            '2015-03-20',
            
            '2015-03-23', 
            '2015-03-24',
            '2015-03-25',
            '2015-03-26',
            '2015-03-27',
    
            '2015-03-30',
            '2015-03-31',
    
            #april
            '2015-04-1', 
            '2015-04-2',
    
            '2015-04-6',
            '2015-04-7',
            '2015-04-8',
            '2015-04-9',
            '2015-04-10',
    
            '2015-04-13',
            '2015-04-14',
            '2015-04-15',
            '2015-04-16',
            '2015-04-17',
    
            '2015-04-20',
            '2015-04-21',
            '2015-04-22',
            '2015-04-23',
            '2015-04-24',
            
            '2015-04-27',
            '2015-04-28',
            '2015-04-29',
            '2015-04-30',
    
            #may
            '2015-05-1', 
           
            '2015-05-4',
            '2015-05-5',
            '2015-05-6',
            '2015-05-7',
            '2015-05-8',
    
            '2015-05-11',
            '2015-05-12',
            '2015-05-13',
            '2015-05-14',
            '2015-05-15',
    
            '2015-05-18',
            '2015-05-19',
            '2015-05-20',
            '2015-05-21',
            '2015-05-22',
    
            '2015-05-26',
            '2015-05-27',
            '2015-05-28',
            '2015-05-29',
    
            #june
            '2015-06-1',
            '2015-06-2',
            '2015-06-3',
            '2015-06-4',
            '2015-06-5',
            
            '2015-06-8',
            '2015-06-9',
            '2015-06-10',
            '2015-06-11',
            '2015-06-12',
    
            '2015-06-15',
            '2015-06-16',
            '2015-06-17',
            '2015-06-18',
            '2015-06-19',
            
            
            '2015-06-22',
            '2015-06-23',
            '2015-06-24',
            '2015-06-25',
            '2015-06-26',
    
            '2015-06-29',
            '2015-06-30',
    
             #july
            '2015-07-1',
            '2015-07-2',
    
            '2015-07-6',
            '2015-07-7',
            '2015-07-8',
            '2015-07-9',
            '2015-07-10',
    
            '2015-07-13',
            '2015-07-14',
            '2015-07-15',
            '2015-07-16',
            '2015-07-17',
    
            '2015-07-20',
            '2015-07-21',
            '2015-07-22',
            '2015-07-23',
            '2015-07-24',
    
            '2015-07-27',
            '2015-07-28',
            '2015-07-29',
            '2015-07-30',
            '2015-07-31',
    
            #august
            '2015-08-3',
            '2015-08-4',
            '2015-08-5',
            '2015-08-6',
            '2015-08-7',
    
            '2015-08-10',
            '2015-08-11',
            '2015-08-12',
            '2015-08-13',
            '2015-08-14',
    
            '2015-08-17',
            '2015-08-18',
            '2015-08-19',
            '2015-08-20',
            '2015-08-21',
    
            '2015-08-24',
            '2015-08-25',
            '2015-08-26',
            '2015-08-27',
            '2015-08-28',
    
            '2015-08-31',
    
            #sept
            '2015-09-1',
            '2015-09-2',
            '2015-09-3',
            '2015-09-4',
    
            '2015-09-8',
            '2015-09-9',
            '2015-09-10',
            '2015-09-11',
    
            '2015-09-14',
            '2015-09-15',
            '2015-09-16',
            '2015-09-17',
            '2015-09-18',
    
            '2015-09-21',
            '2015-09-22',
            '2015-09-23',
            '2015-09-24',
            '2015-09-25',
    
            '2015-09-28',
            '2015-09-29',
            '2015-09-30',
            
            #oct
            '2015-10-1',
            '2015-10-2',
    
            '2015-10-5',
            '2015-10-6',
            '2015-10-7',
            '2015-10-8',
            '2015-10-9',
    
            '2015-10-13',
            '2015-10-14',
            '2015-10-15',
            '2015-10-16',
            
            '2015-10-19',
            '2015-10-20',
            '2015-10-21',
            '2015-10-22',
            '2015-10-23',
            
            '2015-10-26',
            '2015-10-27',
            '2015-10-28',
            '2015-10-29',
            '2015-10-30',
    
            #nov
            '2015-11-2',
            '2015-11-4',
            '2015-11-5',
            '2015-11-6',
    
            '2015-11-9',
            '2015-11-10',
            '2015-11-12',
            '2015-11-13',
    
            '2015-11-16',
            '2015-11-17',
            '2015-11-18',
            '2015-11-19',
            '2015-11-20',
    
            '2015-11-23',
            '2015-11-24',
            '2015-11-25',
            '2015-11-27',
            
            '2015-11-30',
    
            #dec
            '2015-12-1',
            '2015-12-2',
            '2015-12-3',
            '2015-12-4',
    
            '2015-12-7',
            '2015-12-8',
            '2015-12-9',
            '2015-12-10',
            '2015-12-11',

            '2015-12-14',
            '2015-12-15',
            '2015-12-16',
            '2015-12-17',
            '2015-12-18',
    
            '2015-12-21',
            '2015-12-22',
            '2015-12-23',
            '2015-12-24',
          
            '2015-12-28',
            '2015-12-29',
            '2015-12-30',
            '2015-12-31',
    
            #***********
            #2016
            #jan
            '2016-01-4', 
            '2016-01-5', 
            '2016-01-6',
            '2016-01-7',
            '2016-01-8',
    
            '2016-01-11', 
            '2016-01-12', 
            '2016-01-13',
            '2016-01-14',
            '2016-01-15',
    
            '2016-01-19', 
            '2016-01-20', 
            '2016-01-21',
            '2016-01-22',
            
            '2016-01-25', 
            '2016-01-26', 
            '2016-01-27',
            '2016-01-28',
            '2016-01-29',
    
            #feb
            '2016-02-1', 
            '2016-02-2', 
            '2016-02-3',
            '2016-02-4',
            '2016-02-5',
    
            '2016-02-8', 
            '2016-02-9', 
            '2016-02-10',
            '2016-02-11',
            '2016-02-12',
    
            '2016-02-16', 
            '2016-02-17',
            '2016-02-18',
            '2016-02-19',
    
            '2016-02-22', 
            '2016-02-23', 
            '2016-02-24',
            '2016-02-25',
            '2016-02-26',
            
            '2016-02-29',
    
            #march
            '2016-03-1', 
            '2016-03-2', 
            '2016-03-3',
            '2016-03-4',
    
            '2016-03-7', 
            '2016-03-8', 
            '2016-03-9',
            '2016-03-10',
            '2016-03-11',
    
            '2016-03-14', 
            '2016-03-15', 
            '2016-03-16',
            '2016-03-17',
            '2016-03-18',
    
            '2016-03-21', 
            '2016-03-22', 
            '2016-03-23',
            '2016-03-24',
            '2016-03-25',
    
            '2016-03-28', 
            '2016-03-29', 
            '2016-03-30',
            '2016-03-31',
    
            #april
            '2016-04-1', 
    
            '2016-04-4', 
            '2016-04-5', 
            '2016-04-6',
            '2016-04-7',
            '2016-04-8',
    
            '2016-04-11', 
            '2016-04-12', 
            '2016-04-13',
            '2016-04-14',
            '2016-04-15',
            
            '2016-04-18', 
            '2016-04-19', 
            '2016-04-20',
            '2016-04-21',
            '2016-04-22',
            
            '2016-04-25', 
            '2016-04-26', 
            '2016-04-27',
            '2016-04-28',
            '2016-04-29',
    
            #may
            '2016-05-2', 
            '2016-05-3', 
            '2016-05-4',
            '2016-05-5',
            '2016-05-6',
    
            '2016-05-9', 
            '2016-05-10', 
            '2016-05-11',
            '2016-05-12',
            '2016-05-13',
    
            '2016-05-16', 
            '2016-05-17', 
            '2016-05-18',
            '2016-05-19',
            '2016-05-20',
    
            '2016-05-23', 
            '2016-05-24', 
            '2016-05-25',
            '2016-05-26',
            '2016-05-27',
    
            '2016-05-31',
    
            #june
            '2016-06-1', 
            '2016-06-2', 
            '2016-06-3',

            '2016-06-6', 
            '2016-06-7', 
            '2016-06-8',
            '2016-06-9',
            '2016-06-10',
    
            '2016-06-13', 
            '2016-06-14', 
            '2016-06-15',
            '2016-06-16',
            '2016-06-17',
            
            '2016-06-20', 
            '2016-06-21', 
            '2016-06-22',
            '2016-06-23',
            '2016-06-24',
    
            '2016-06-27', 
            '2016-06-28', 
            '2016-06-29',
            '2016-06-30',
            
    
            #july
            '2016-07-1',
    
            '2016-07-5', 
            '2016-07-6', 
            '2016-07-7',
            '2016-07-8',
            
    
            '2016-07-11', 
            '2016-07-12', 
            '2016-07-13',
            '2016-07-14',
            '2016-07-15',
            
            '2016-07-18', 
            '2016-07-19', 
            '2016-07-20',
            '2016-07-21',
            '2016-07-22',
    
            '2016-07-25', 
            '2016-07-26', 
            '2016-07-27',
            '2016-07-28',
            '2016-07-29',
           
           #august
            '2016-08-1',
            '2016-08-2',
            '2016-08-3',
            '2016-08-4',
            '2016-08-5',
           
            '2016-08-8',
            '2016-08-9',
            '2016-08-10',
            '2016-08-11',
            '2016-08-12',
           
            '2016-08-15',
            '2016-08-16',
            '2016-08-17',
            '2016-08-18',
            '2016-08-19',
           
            '2016-08-22',
            '2016-08-23',
            '2016-08-24',
            '2016-08-25',
            '2016-08-26',
           
            '2016-08-29',
            '2016-08-30',
            '2016-08-31',
           
           #september
            '2016-09-1',
            '2016-09-2',
           
            '2016-09-6',
            '2016-09-7',
            '2016-09-8',
            '2016-09-9',
           
            '2016-09-12',
            '2016-09-13',
            '2016-09-14',
            '2016-09-15',
            '2016-09-16',
           
            '2016-09-19',
            '2016-09-20',
            '2016-09-21',
            '2016-09-22',
            '2016-09-23',
           
            '2016-09-26',
            '2016-09-27',
            '2016-09-28',
            '2016-09-29',
            '2016-09-30',
    
            #october
            '2016-10-3',
            '2016-10-4',
            '2016-10-5',
            '2016-10-6',
            '2016-10-7',
           
            '2016-10-11',
            '2016-10-12',
            '2016-10-13',
            '2016-10-14',
            
            '2016-10-17',
            '2016-10-18',
            '2016-10-19',
            '2016-10-20',
            '2016-10-21',
    
            '2016-10-24',
            '2016-10-25',
            '2016-10-26',
            '2016-10-27',
            '2016-10-28',
    
            '2016-10-31',
    
            #november
            '2016-11-1',
            '2016-11-2',
            '2016-11-3',
            '2016-11-4',
            
            '2016-11-7',
            '2016-11-9',
            '2016-11-10',
            
            '2016-11-14',
            '2016-11-15',
            '2016-11-16',
            '2016-11-17',
            '2016-11-18',

            '2016-11-21',
            '2016-11-22',
            '2016-11-23',
            '2016-11-25',
    
            '2016-11-28',
            '2016-11-29',
            '2016-11-30',
           
            
          ]

wd = pd.DataFrame({'workdays': wd_list })
wd['workdays'] = pd.to_datetime(wd['workdays'])

# %% [markdown]
# # Part 2: Read Data

# %%
dfs = pd.read_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\Front Line Workers\\supervisors_wo_crossfunc_group.csv")

df = pd.read_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\jan to dec 2015\\Leave Requests Report jan 1 2015 to dec 31 2015.csv")
dfr = pd.read_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\jan-sept 2016\\Leave Requests Report jan-sept 2016.csv")

#strip out special characters
dfs["Supervisor"] = dfs["Supervisor"].str.replace('[^\x00-\x7F]','')
#format string
dfs["Supervisor"] = dfs["Supervisor"].astype(str)
dfs["Supervisor"] = dfs["Supervisor"].map(str.strip)
dfs["Supervisor"] = dfs["Supervisor"].map(str.upper)
dfs["Supervisor"] = dfs["Supervisor"].str.replace(' JR','')
dfs["Supervisor"] = dfs["Supervisor"].str.replace('  ',' ')
dfs["Supervisor"] = dfs["Supervisor"].str.replace(' - ','-')
dfs["Supervisor"] = dfs["Supervisor"].str.replace('- ','-')
dfs["Supervisor"] = dfs["Supervisor"].str.replace(' -','-')
dfs["Supervisor"] = dfs["Supervisor"].map(str.strip)

    
#Combine 2015 and 2016

df = df[["Approval Org/Command", "CityTime ID", "Last Name", "First Name", "Title","Start Time", "End Time", "Duration", "Leave Type", "Leave Reason" ]]

df["Approval Org/Command"] = df["Approval Org/Command"].astype(str)
df["Approval Org/Command"] = df["Approval Org/Command"].map(str.strip)

df["Approval Org/Command"] = df["Approval Org/Command"].map(str.upper)

dfr = dfr[["Approval Org/Command", "CityTime ID", "Last Name", "First Name", "Title","Start Time", "End Time", "Duration", "Leave Type", "Leave Reason" ]]

dfr["Approval Org/Command"] = dfr["Approval Org/Command"].astype(str)
dfr["Approval Org/Command"] = dfr["Approval Org/Command"].map(str.strip)

dfr["Approval Org/Command"] = dfr["Approval Org/Command"].map(str.upper)

print len(df)
print len(dfr)

frames = [df, dfr]

df = pd.concat(frames)

df = df.reset_index(drop=True)

#strip out special characters from dataframe
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace('[^\x00-\x7F]','')
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace(' JR','')
df["Approval Org/Command"] = df["Approval Org/Command"].map(str.strip)

df["Approval Org/Command"] = df["Approval Org/Command"].str.replace('  ',' ')
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace(' - ','-')
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace('- ','-')
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace('-  ','-')
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace(' -','-')
df["Approval Org/Command"] = df["Approval Org/Command"].str.replace(' -','-')


df["Approval Org/Command"] = df["Approval Org/Command"].map(str.strip)


print len(df)
# Out:
# 47801
# 40891
# 88692

# %% [markdown]
# # Part 2b: Subset Data for Dates of Interest

# %%
df["Start Time"] = pd.to_datetime(df['Start Time'])
df["End Time"] = pd.to_datetime(df['End Time'])

#start_time = str(lv["Start Time"][i].month) + '-' + str(lv["Start Time"][i].day) + '-' + str(lv["Start Time"][i].year)
#end_time = str(lv["End Time"][i].month) + '-' + str(lv["End Time"][i].day) + '-' + str(lv["End Time"][i].year)

start_time = '1-1-2016'
end_time = '9-30-2016'
#subset the days worked using mask
mask = (df['Start Time'] >= start_time)
df = df.loc[mask]

df = df.reset_index(drop=True)

# %% [markdown]
# # Part 3: Get People of Interest for Analysis

# %%
#get the people of interest for analysis
pd.set_option('chained_assignment', None)

print "getting people of interest ..."

df["Name"] = df["First Name"] + " " + df["Last Name"]


#create supervisor list
list_sup = []

for i in range(0, len(dfs)):
    list_sup.append(dfs["Supervisor"][i])


names = []
supervisor = []

qn = pd.DataFrame(columns=('Approval Org/Command', 'CityTime ID', 'Last Name', 'First Name', 'Title', 'Start Time', 'End Time', 'Duration', 'Leave Type', 'Leave Reason'))



for i in range(0, len(df)):
    if df["Approval Org/Command"][i] in list_sup:
        names.append(df["Name"][i])
        supervisor.append(df["Approval Org/Command"][i])
        qn.loc[i] = [df["Approval Org/Command"][i],df["CityTime ID"][i],df["Last Name"][i], df["First Name"][i],df["Title"][i],\
                     df["Start Time"][i], df["End Time"][i],df["Duration"][i], df["Leave Type"][i],df["Leave Reason"][i] ]

        
qn["Name"] = qn["First Name"] + " " + qn["Last Name"]        


qn = qn.reset_index(drop=True)      
dfs = dfs.reset_index(drop=True)      



qn = qn.reset_index(drop=True)      

#print len(names)      
names = set(names)
print "number of people", len(names)

supervisor = set(supervisor)
print "number of supervisors in supervisor list", len(supervisor)

print "number of supervisors in shannons list", len(dfs)

print "Done"
# Out:
# getting people of interest ...
# number of people 79
# number of supervisors in supervisor list 21
# number of supervisors in shannons list 21
# Done

# %% [markdown]
# # Part 4: Calculate Month and Year for Correct Leave Calculation

# %%
#get month and year
print "Calculating month and year ..."
pd.set_option('chained_assignment', None)

qn["Start Time"] = pd.to_datetime(qn['Start Time'])
qn["End Time"] = pd.to_datetime(qn['End Time'])


qn["Start Month"] = ""
qn["End Month"] = ""
qn["Year"] = ""
#get rid of start and end dates not in august
for i in range(0, len(qn)):
    qn["Start Month"][i] = qn["Start Time"][i].month
    qn["End Month"][i] = qn["End Time"][i].month


for i in range (0, len(qn)):
    qn["Year"][i] = qn["Start Time"][i].year
    
print "Done"
# Out:
# Calculating month and year ...
# Done

# %% [markdown]
# # Part 5: Calculate Correct Leave

# %%
#TIME CORRECTION

pd.set_option('chained_assignment', None)


qn["Inspector"] = 0


lv = qn

lv["DateMonthYear"] = ""
lv["C Duration"] = 0.0

print "Calculating correct leave ..."

import datetime

pd.set_option('chained_assignment', None)
count_same_day = 0

#minute to hour time converter
def HourConverter (a):
    a = str(a)
    a = a.split(":")

    hour = float(a[0])
    minutes = float(a[1])
    minutes_to_hours = float(minutes/60.0)

    total = hour + minutes_to_hours
    
    return total

def CalcDuration(month, wd_subset, start_time, end_time, lv):
    #Calculates the duration and calls on hour converter when start and end day are same
    #wd_subset = wd_subset[wd_subset.workdays.dt.year == z]
    wd_subset2 = wd_subset[wd_subset.workdays.dt.month == month]
    days_leave = len(wd_subset2)

    hours_leave = 7*days_leave
    
    #if (start_time == end_time and len(wd_subset2) != 0): 
    if (start_time == end_time): 
        a = lv["Duration"][i]

        hours_leave = HourConverter (a)
  
        
    return hours_leave

 
def CalcDuration2(month, wd_subset, start_time, end_time, lv):
    #Calculates the duration for the days in the next month, for cases where leave goes into the next month
    #get the next month

  
    wd_subset3 = wd_subset[wd_subset.workdays.dt.month == month]
    
    days_leave = len(wd_subset3)
    hours_leave = 7*days_leave
        
    return hours_leave
    

    
next_month = pd.DataFrame(columns=('Approval Org/Command', 'CityTime ID', 'Last Name', 'First Name', 'Title', \
                                   'Start Time', 'End Time', 'Duration', 'Leave Type', \
                                   'Leave Reason', 'Name', 'Inspector', 'DateMonthYear', 'C Duration', 'Start Month', 'End Month', 'Year'))


lv = lv.reset_index(drop=True)

for i in range(0, len(lv)):
    if i%1000 == 0:
        print i

    start_time = str(lv["Start Time"][i].month) + '-' + str(lv["Start Time"][i].day) + '-' + str(lv["Start Time"][i].year)
    end_time = str(lv["End Time"][i].month) + '-' + str(lv["End Time"][i].day) + '-' + str(lv["End Time"][i].year)

    #subset the days worked using mask
    mask = (wd['workdays'] >= start_time) & (wd['workdays'] <= end_time)
    wd_subset = wd.loc[mask]
            
    lv["C Duration"][i] = CalcDuration( lv["Start Time"][i].month,  wd_subset,  start_time,  end_time, lv)
            
    lv["DateMonthYear"][i] = start_time
            
    #if start and and month not same, need to calcualte the leave in the next month
    if  lv["Start Month"][i] != lv["End Month"][i]:
        #next month duration
        nm_duration = CalcDuration2( lv["End Time"][i].month, wd_subset, start_time, end_time, lv)
        
        dateMonthYear = end_time
                
        #'Approval Org/Command', 'CityTime ID', 'Last Name', 'First Name', 'Title', 'Start Time', 'End Time', 'Duration', 'Leave Type', 'Leave Reason', 'Name', 'Inspector', 'DateMonthYear', 'C Duration', 'Start Month', 'End Month', 'Year'
        next_month.loc[i] = [ lv["Approval Org/Command"][i], lv["CityTime ID"][i], lv["Last Name"][i], lv["First Name"][i], lv["Title"][i], \
                             lv["Start Time"][i], lv["End Time"][i], lv["Duration"][i], lv["Leave Type"][i], \
                            lv["Leave Reason"][i], lv["Name"][i], lv["Inspector"][i], dateMonthYear, nm_duration, lv["Start Month"][i], lv["End Month"][i], lv["Year"][i]  ]
                    


next_month = next_month.reset_index(drop=True)
                                                                        
print "Done"
# Out:
# Calculating correct leave ...
# 0
# 1000
# 2000
# 3000
# Done

# %% [markdown]
# # Part 7: MERGE DATASETS AND ASSIGN BOROUGH AND JOB FUNCTION

# %%
frames = [lv, next_month]

export = pd.concat(frames)

export = export.reset_index(drop=True)
print "Merging datasets ..."
print len(lv)
print len(next_month)
print len(export)

export = export[["Approval Org/Command", "CityTime ID", "Last Name", "First Name", "Title", \
                             "Start Time", "End Time", "Duration", "Leave Type", \
                            "Leave Reason", "Inspector", "DateMonthYear", "C Duration", "Start Month", "End Month", "Year" ]]


#Assign boro to each employee based on supervisor
#create dictory from dataframe
dfsDic = dfs.set_index('Supervisor').T.to_dict('list')



export["Boro"] = ""

for i in range(0, len(export)):
    export["Boro"][i] = dfsDic[export["Approval Org/Command"][i]][0]

export["Boro"] = export["Boro"].astype(str)
export["Boro"] = export["Boro"].str.replace(']','')
export["Boro"] = export["Boro"].str.replace('[','')

#Remove all rows of data with central unit, not important for this analysis
print "length of export", len(export)
export = export[export["Boro"] != "Central Unit"]
print "length of export after removing central unit", len(export)
export = export.reset_index(drop=True)


print "Assigning job function Boro ..."
#JOB FUNCTION

export["Job Function"] = ""

print "Assigning Job Function"

for i in range(0, len(export)):
    export["Job Function"][i] = dfsDic[export["Approval Org/Command"][i]][1]

print "Done"


#rename cross functional with app processing 
#export["Job Function"] = export["Job Function"].str.replace('Cross Functional', 'App Processing')

#remove cross functional team because may skew results, these people do not spend much time at front line
export = export[export["Job Function"] != "Cross Functional"]
export = export.reset_index(drop=True)


#add month of leave
export["Leave Month"] = ""
for i in range(0, len(export)):
    a = export["DateMonthYear"][i]
    a = a.split("-")
    export["Leave Month"][i] = a[0]
    


#subset for december 2015 through sept 2016
export["DateMonthYear"] = pd.to_datetime(export["DateMonthYear"])

start_time = "12-1-2015"

mask = (export['DateMonthYear'] >= start_time)
export = export.loc[mask]
export = export.reset_index(drop=True)
# Out:
# Merging datasets ...
# 3568
# 26
# 3594
# length of export 3594
# length of export after removing central unit 3594
# Assigning job function Boro ...
# Assigning Job Function
# Done

# %% [markdown]
# # Part 7b: Get rid of Zero Duration

# %%
export = export.reset_index(drop=True)
count = 0
for i in range(0, len(export)):
    if export["C Duration"][i] == 0:
        count += 1
        a = export["Duration"][i]
        a = a.split(":")
        export["C Duration"][i] = int(a[0])

print "how many zero duration...", count
# Out:
# how many zero duration... 0

# %%
export.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\Front Line Workers\\total_leave_frontline 2.csv")

# %%
export
# Out:
#                   Approval Org/Command  CityTime ID       Last Name  \
# 0         APP PROCESSING DIV-HERNANDEZ      97070.0         GADSDEN
# 1                          BSCAN-ROMAN      97442.0         BINGLEY
# 2            CERT.OF OCCUPANCY-EDWARDS      97235.0        FERGUSON
# 3            CERT.OF OCCUPANCY-EDWARDS      97235.0        FERGUSON
# 4         APP PROCESSING DIV-HERNANDEZ      97437.0         EDWARDS
# 5                   RECORD ROOM-GRAHAM      97056.0         MCCLAIN
# 6         APP PROCESSING DIV-HERNANDEZ      97380.0        GONZALEZ
# 7         APP PROCESSING DIV-HERNANDEZ      97965.0        GRIMALDI
# 8                          BSCAN-ROMAN      97116.0  BERNARD-SPENCE
# 9                        C OF O-RANSOM     445915.0         HASKINS
# 10          APP PROC SNOFF UNITS-LINDO     402888.0           ABREU
# 11        APP PROCESSING DIV-HERNANDEZ      97975.0          MARTIN
# 12    APPLICATION PROCESSING-SMALLWOOD      97448.0            HALL
# ...

# %%
export["Boro"][0]
# Out:
# 'Manhattan'

# %%
#New measure to measure hours of leave, number of leave hours divided by the working hour capacity

#number of employees per unit
num_emp = {}

export["Leave Month"] = export["Leave Month"].astype(int)

branch_boro = ['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island']

#dataframe for number of employees per unit
exportNE = pd.DataFrame(columns=('Month', 'Boro', 'Job Function', 'Number of Employees'))

index = 0
#length of months = 9
for i in range(1, 10):
    export2 = export
    
    export2 = export[export["Leave Month"] == i]
    export2 = export2.reset_index(drop=True)
    
    

    #print export2["Leave Month"]
    
    #subset to get boro
    
    for j in range(0, len(branch_boro)):
         
        export3 = export2[export2["Boro"] == branch_boro[j]]
        #print export3["Boro"]
        export3 = export3.reset_index(drop=True)

        
        #job function list
        jf_list = []
        
        #print len(export3)
        
        #create list of job functions per boro
        for counter in range(0, len(export3)):
            jf_list.append(export3["Job Function"][counter])
            
        
        jf_list = set(jf_list)
        jf_list = list(jf_list)
        
        for z in range(0, len(jf_list)):
            index += 1 
            #subset to get job function, each job function will have x number of people
            export4 =  export3[export3["Job Function"] == jf_list[z]]
            #n_employees = len(export4)
            #print jf_list[z], n_employees
            #print export4["Last Name"]
            
            n_employees = len(export4.groupby(['Last Name', 'First Name']).count() )
            #print i,branch_boro[j], jf_list[z], n_employees

            exportNE.loc[index] = [i,branch_boro[j],jf_list[z], n_employees]

# %%
#NUMBER OF WORKING HOURS PER MONTH IN 2016
exportNE = exportNE.reset_index(drop=True)




exportNE["Month"] = exportNE["Month"].astype(int)

exportNE["Total Working Hour Capacity"] = ""

#number working days * 7 hours of work per day per employee
JAN = 19*7
FEB = 20*7
MAR = 23*7
APR = 21*7
MAY = 21*7
JUN = 22*7
JUL = 20*7
AUG = 23*7
SEP = 21*7

for i in range(0, len(exportNE)):
    if exportNE["Month"][i] == 1:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*JAN
    if exportNE["Month"][i] == 2:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*FEB
    if exportNE["Month"][i] == 3:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*MAR
    if exportNE["Month"][i] == 4:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*APR
        
    if exportNE["Month"][i] == 5:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*MAY
        
    if exportNE["Month"][i] == 6:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*JUN
        
    if exportNE["Month"][i] == 7:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*JUL
    
    if exportNE["Month"][i] == 8:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*AUG
        
    if exportNE["Month"][i] == 9:
        exportNE["Total Working Hour Capacity"][i] = exportNE["Number of Employees"][i]*SEP

# %%
exportNE
# Out:
#      Month           Boro              Job Function  Number of Employees  \
# 0        1      Manhattan            App Processing                 11.0
# 1        1      Manhattan                   Records                 15.0
# 2        1      Manhattan  Certificate of Occupancy                  5.0
# 3        1       Brooklyn            App Processing                  5.0
# 4        1       Brooklyn                   Records                  4.0
# 5        1       Brooklyn  Certificate of Occupancy                  2.0
# 6        1         Queens            App Processing                  6.0
# 7        1         Queens  Certificate of Occupancy                  2.0
# 8        1          Bronx            App Processing                  2.0
# 9        1          Bronx                   Records                  2.0
# 10       1          Bronx  Certificate of Occupancy                  2.0
# 11       1  Staten Island            App Processing                  5.0
# ...

# %%
#group to add up the sum of leave for each group
exportG = export.groupby(['Leave Month', 'Boro', 'Job Function']).sum()
exportG = exportG.add_suffix('_Count').reset_index()
exportG = exportG[["Leave Month", "Boro", "Job Function", "C Duration_Count"]]
exportG = exportG.rename(columns={'C Duration_Count': 'Total Leave Hours'})

exportG["Leave Month"] = exportG["Leave Month"].astype(int)

#sort by leave month, ascending
exportG = exportG.sort_values(by = 'Leave Month', ascending=True).reset_index(drop=True)



exportG
# Out:
#      Leave Month           Boro              Job Function  Total Leave Hours
# 0              1          Bronx            App Processing          24.250000
# 1              1  Staten Island  Certificate of Occupancy          10.500000
# 2              1  Staten Island            App Processing          86.750000
# 3              1         Queens  Certificate of Occupancy          84.500000
# 4              1      Manhattan                   Records         431.916667
# 5              1      Manhattan  Certificate of Occupancy         213.166667
# 6              1         Queens            App Processing         106.966667
# 7              1       Brooklyn                   Records         107.000000
# 8              1       Brooklyn  Certificate of Occupancy          76.250000
# 9              1       Brooklyn            App Processing         121.000000
# 10             1          Bronx                   Records          34.250000
# ...

# %%
#CALCULATE THE MEAN FOR EACH GROUP

export2 = export

export2 = export2[export2['C Duration'] > 3.5]

exportGM = export2.groupby(['Leave Month', 'Boro', 'Job Function']).mean()
exportGM = exportGM.add_suffix('_Count').reset_index()
exportGM = exportGM[["Leave Month", "Boro", "Job Function", "C Duration_Count"]]
exportGM = exportGM.rename(columns={'C Duration_Count': 'Avg Leave Hours'})

exportGM["Leave Month"] = exportGM["Leave Month"].astype(int)

#sort by leave month, ascending
exportGM = exportGM.sort_values(by = 'Leave Month', ascending=True).reset_index(drop=True)


exportGM
# Out:
#      Leave Month           Boro              Job Function  Avg Leave Hours
# 0              1          Bronx            App Processing         6.166667
# 1              1  Staten Island  Certificate of Occupancy         7.000000
# 2              1  Staten Island            App Processing         9.333333
# 3              1         Queens  Certificate of Occupancy         7.636364
# 4              1      Manhattan                   Records        10.941176
# 5              1      Manhattan  Certificate of Occupancy         8.909091
# 6              1         Queens            App Processing         7.000000
# 7              1       Brooklyn                   Records         9.545455
# 8              1       Brooklyn  Certificate of Occupancy        11.125000
# 9              1       Brooklyn            App Processing         7.383333
# 10             1          Bronx                   Records         7.000000
# ...

# %% [markdown]
# # Part 8: Export

# %%
export.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\Front Line Workers\\front line workers leave jan 2015 - sept 2016 4.csv")

# %%
dfsDic['AEU CUSTOMER SERVICE-MASTRORILLI'][0]

# %%
export

# %%
export

# %% [markdown]
# # Part 9: QMATIC Data

# %%
import pandas as pd

#IN THIS PART NEED TO CODE THE QMATIC DATA BASED ON JOB FUNCTION AND THEN INSERT THE LEAVE TIM PER GROUP

qm = pd.read_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\Front Line Workers\\qmatic average time feb - sept 2016.csv")

#REMOVE DECEMBER 2015
qm = qm[qm["Month"] != "December"]

# %%
qm = qm.drop('Boro or Central', 1)

# %%
qm = qm.rename(columns={'Queue Name': 'Queue_Name'})

# %%
print "len of qm before removing", len(qm)

#drop queeue name that is not relevant to analysis
qm["Queue_Name"] = qm["Queue_Name"].astype(str)
qm = qm[qm.Queue_Name.str.contains("Development") == False]
qm = qm[qm.Queue_Name.str.contains("Enforcement") == False]
qm = qm[qm.Queue_Name.str.contains("Fee Estimator") == False]
qm = qm[qm.Queue_Name.str.contains("House Connections") == False]
qm = qm[qm.Queue_Name.str.contains("4th") == False]
qm = qm[qm.Queue_Name.str.contains("5th") == False]
qm = qm[qm.Queue_Name.str.contains("6th") == False]
qm = qm[qm.Queue_Name.str.contains("Fee Adjustments and Penalties") == False]
qm = qm[qm.Queue_Name.str.contains("Quality of Life") == False]


qm = qm.reset_index(drop=True)

print "len of qm after removing", len(qm)
# Out:
# len of qm before removing 690
# len of qm after removing 316

# %%
pd.set_option('chained_assignment', None)

qm["Job Function"] = ""

#Code the qmatic data
for i in range(0, len(qm)):
    if "App" in qm["Queue_Name"][i]:
        qm["Job Function"][i] = "App Processing" 
    if "Express Cashier" in qm["Queue_Name"][i]:
        qm["Job Function"][i] = "App Processing"
    if "Cert of" in qm["Queue_Name"][i]:
        qm["Job Function"][i] = "Certificate of Occupancy"
    if "Record" in qm["Queue_Name"][i]:
        qm["Job Function"][i] = "Records"
    if "Microfilm" in qm["Queue_Name"][i]:
        qm["Job Function"][i] = "Records"
    if "Property Research" in qm["Queue_Name"][i]:
        qm["Job Function"][i] = "Records"
    
    


    #if "Cert of" in q["Queue_Name"][i]:
    #    qm["Job Function"][i] = "Cert of Occupancy"

# %%
#Calculate Wait time and transaction time in hours
#qm["Total Wait Time"] = qm["Total Wait Time"].astype(str)
#qm["Total Wait Time"] = qm["Total Wait Time"].astype(float)

qm["Avg. Wait. Time (hours)"] = qm["Avg. Wait. Time (min)"]/60.0
qm["Avg. Trans. Time (hours)"] = qm["Avg. Trans. Time (min)"]/60.0
qm["Total Wait Time (hours)"] = qm["Total Wait Time"]/60.0
qm["Total Transaction Time (hours)"] = qm["Total Transaction Time"]/60.0

# %%
qm["Branch Name"] = qm["Branch Name"].str.replace('Borough', '') 

qm["Month2"] = ""
qm["Year"] = ""
#Add Month and Year
for i in range(0, len(qm)):
    if qm["Month"][i] == "December":
        qm["Month2"][i] = 12
        qm["Year"][i] = 2015
    if qm["Month"][i] == "January":
        qm["Month2"][i] = 1
        qm["Year"][i] = 2016
    if qm["Month"][i] == "February":
        qm["Month2"][i] = 2
        qm["Year"][i] = 2016
    if qm["Month"][i] == "March":
        qm["Month2"][i] = 3
        qm["Year"][i] = 2016
    if qm["Month"][i] == "April":
        qm["Month2"][i] = 4
        qm["Year"][i] = 2016
    if qm["Month"][i] == "May":
        qm["Month2"][i] = 5
        qm["Year"][i] = 2016 
    if qm["Month"][i] == "June":
        qm["Month2"][i] = 6
        qm["Year"][i] = 2016 
    if qm["Month"][i] == "July":
        qm["Month2"][i] = 7
        qm["Year"][i] = 2016  
    if qm["Month"][i] == "August":
        qm["Month2"][i] = 8
        qm["Year"][i] = 2016 
    if qm["Month"][i] == "September":
        qm["Month2"][i] = 9
        qm["Year"][i] = 2016

# %% [markdown]
# # Part 10: Merge the Qmatic and Leave Datasets

# %%
exportG["Boro"] = exportG["Boro"].map(str.upper)
exportG["Boro"] = exportG["Boro"].map(str.strip)
exportG["Job Function"] = exportG["Job Function"].map(str.upper)
exportG["Job Function"] = exportG["Job Function"].map(str.strip)


exportNE["Boro"] = exportNE["Boro"].map(str.upper)
exportNE["Boro"] = exportNE["Boro"].map(str.strip)
exportNE["Job Function"] = exportNE["Job Function"].map(str.upper)
exportNE["Job Function"] = exportNE["Job Function"].map(str.strip)

#exportG["Leave Month"] = exportG["Leave Month"].map(str.strip)


exportGM["Boro"] = exportGM["Boro"].map(str.upper)
exportGM["Boro"] = exportGM["Boro"].map(str.strip)
exportGM["Job Function"] = exportGM["Job Function"].map(str.upper)
exportGM["Job Function"] = exportGM["Job Function"].map(str.strip)
#exportG["Leave Month"] = exportG["Leave Month"].map(str.strip)




qm["Branch Name"] = qm["Branch Name"].map(str.upper)
qm["Branch Name"] = qm["Branch Name"].map(str.strip)
qm["Job Function"] = qm["Job Function"].map(str.upper)
qm["Job Function"] = qm["Job Function"].map(str.strip)
qm["Month2"] = qm["Month2"].astype(str)
qm["Month2"] = qm["Month2"].map(str.strip)
qm["Month2"] = qm["Month2"].astype(int)
qm = qm.sort_values(by = 'Month2', ascending=True).reset_index(drop=True)

# %%
#group the qmatic dataset

qm["Arrived"] = qm["Arrived"].astype(int)
qm["Served"] = qm["Served"].astype(int)

qmG = qm.groupby(['Month2', 'Branch Name', 'Job Function']).sum()
qmG = qmG.add_suffix('_Count').reset_index()

qmG = qmG.rename(columns={'Total Wait Time (hours)_Count': 'Total Wait Time (hours)', 'Total Transaction Time (hours)_Count': 'Total Transaction Time (hours)'})
qmG = qmG.rename(columns={'Arrived_Count': 'Arrived', 'Served_Count': 'Served'})
                         
qmG  = qmG[["Month2", "Branch Name", "Job Function","Arrived", "Served", "Total Wait Time (hours)", "Total Transaction Time (hours)"]]

qmG["Avg Wait Time (hours)"] = qmG["Total Wait Time (hours)"]/qmG["Served"]
qmG["Avg Transaction Time (hours)"] = qmG["Total Transaction Time (hours)"]/qmG["Served"]

# %%
qmG["Total Leave (Hours)"] = ""

qmG["Avg Leave (Hours)"] = ""

qmG["Number of Employees"] = ""

qmG["Total Working Hour Capacity"] = ""


for i in range(0,len(exportG)):
    for j in range(0, len(qmG)):
        if (exportG["Leave Month"][i] == qmG["Month2"][j] and exportG["Boro"][i] == qmG["Branch Name"][j] and exportG["Job Function"][i] == qmG["Job Function"][j]):
            qmG["Total Leave (Hours)"][j] = exportG["Total Leave Hours"][i]
            
for i in range(0,len(exportGM)):
    for j in range(0, len(qmG)):
        if (exportGM["Leave Month"][i] == qmG["Month2"][j] and exportGM["Boro"][i] == qmG["Branch Name"][j] and exportGM["Job Function"][i] == qmG["Job Function"][j]):
            #print "in here"
            qmG["Avg Leave (Hours)"][j] = exportGM["Avg Leave Hours"][i]
            
            
for i in range(0,len(exportNE)):
    for j in range(0, len(qmG)):
        if (exportNE["Month"][i] == qmG["Month2"][j] and exportNE["Boro"][i] == qmG["Branch Name"][j] and exportNE["Job Function"][i] == qmG["Job Function"][j]):
            #print "in here"
            qmG["Number of Employees"][j] = exportNE["Number of Employees"][i]
            qmG["Total Working Hour Capacity"][j] = exportNE["Total Working Hour Capacity"][i]


print "Drop NAs"
print "length of qmG", len(qmG)
qmG = qmG[qmG["Total Leave (Hours)"] != ""]
qmG = qmG.reset_index(drop=True)
#qmG = qmG.dropna()
print "length of qmG after drop NA", len(qmG)

#calculating leave index
print "calculating leave index ..."
qmG["Leave Index"] = qmG["Total Leave (Hours)"]/qmG["Total Working Hour Capacity"]
# Out:
# Drop NAs
# length of qmG 125
# length of qmG after drop NA 125
# calculating leave index ...

# %%
qmG
# Out:
#      Month2    Branch Name              Job Function  Arrived  Served  \
# 0         1          BRONX            APP PROCESSING     1407    1254
# 1         1          BRONX  CERTIFICATE OF OCCUPANCY      538     534
# 2         1          BRONX                   RECORDS      903     882
# 3         1       BROOKLYN            APP PROCESSING     3300    2783
# 4         1       BROOKLYN  CERTIFICATE OF OCCUPANCY      992     869
# 5         1       BROOKLYN                   RECORDS      328     272
# 6         1      MANHATTAN            APP PROCESSING     8704    7804
# 7         1      MANHATTAN  CERTIFICATE OF OCCUPANCY     2752    2512
# 8         1      MANHATTAN                   RECORDS     2250    2125
# 9         1         QUEENS            APP PROCESSING     3574    3080
# 10        1         QUEENS  CERTIFICATE OF OCCUPANCY     1411    1147
# 11        1  STATEN ISLAND            APP PROCESSING      856     813
# ...

# %%
qmG.to_csv("S:\\Office of Risk Management\\User Folders\\Darius Mehri\\Enforcement Inspection Analysis\\Front Line Workers\\qmatic and leave 2016 6.csv")

# %% [markdown]
# # ***************************************

# %% [markdown]
# # OLD CODE

# %%
#TIME CORRECTION

pd.set_option('chained_assignment', None)


qn["Inspector"] = 0


lv = qn

lv["DateMonthYear"] = ""
lv["C Duration"] = 0.0

print "Running"

import datetime

pd.set_option('chained_assignment', None)
count_same_day = 0

#minute to hour time converter
def HourConverter (a):
    a = str(a)
    a = a.split(":")

    hour = float(a[0])
    minutes = float(a[1])
    minutes_to_hours = float(minutes/60.0)

    total = hour + minutes_to_hours
    
    return total

def CalcDuration(month, year, wd_subset, start_time, end_time, lv):
    #Calculates the duration and calls on hour converter when start and end day are same
    #wd_subset = wd_subset[wd_subset.workdays.dt.year == z]
    wd_subset2 = wd_subset[wd_subset.workdays.dt.month == j]
    days_leave = len(wd_subset2)

    hours_leave = 7*days_leave
    
    if (start_time == end_time and len(wd_subset2) != 0): 
        a = lv["Duration"][i]

        hours_leave = HourConverter (a)
        
        
        if (lv["Start Month"][i] > j and lv["End Month"][i] > j):
            hours_leave = 0.0
                        
        if (lv["Start Month"][i] < j and lv["End Month"][i] < j):
            hours_leave = 0.0
        
    return hours_leave

 
def CalcDuration2(month, year, wd_subset, start_time, end_time, lv):
    #Calculates the duration for the days in the next month, for cases where leave goes into the next month
    #get the next month
    m = j+1
    wd_subset3 = wd_subset[wd_subset.workdays.dt.month == m]
    days_leave = len(wd_subset3)

    hours_leave = 7*days_leave
    
    if (start_time == end_time and len(wd_subset3) != 0): 
        a = lv["Duration"][i]

        hours_leave = HourConverter (a)
        
        if (lv["Start Month"][i] > j and lv["End Month"][i] > j):
            hours_leave = 0.0
                        
        if (lv["Start Month"][i] < j and lv["End Month"][i] < j):
            hours_leave = 0.0
        
    return hours_leave
    

    
next_month = pd.DataFrame(columns=('Approval Org/Command', 'CityTime ID', 'Last Name', 'First Name', 'Title', 'Start Time', 'End Time', 'Duration', 'Leave Type', 'Leave Reason', 'Name', 'Inspector', 'DateMonthYear', 'C Duration', 'Start Month', 'End Month', 'Year'))


lv = lv.reset_index(drop=True)

for z in range(2015, 2017):
  
    for j in range(1, 13):

        print "month = ", j, "year= ", z

        for i in range(0, len(lv)):
            if i%10000 == 0:
                print i

            start_time = str(lv["Start Time"][i].month) + '-' + str(lv["Start Time"][i].day) + '-' + str(lv["Start Time"][i].year)
            end_time = str(lv["End Time"][i].month) + '-' + str(lv["End Time"][i].day) + '-' + str(lv["End Time"][i].year)

            #subset the days worked using mask
            mask = (wd['workdays'] >= start_time) & (wd['workdays'] <= end_time)
            wd_subset = wd.loc[mask]
            
            lv["C Duration"][i] = CalcDuration(j, z, wd_subset, start_time, end_time, lv)
            
            lv["DateMonthYear"][i] = str(lv["Start Time"][i].month) + '-' + str(lv["Start Time"][i].year)
            
            #if start and and month not same, need to calcualte the leave in the next month
            if lv["End Month"][i] > lv["Start Month"][i]:
                #next month duration
                nm_duration = CalcDuration2(j, z, wd_subset, start_time, end_time, lv)
                dateMonthYear = str(lv["End Time"][i].month) + '-' + str(lv["End Time"][i].year)
                
                #'Approval Org/Command', 'CityTime ID', 'Last Name', 'First Name', 'Title', 'Start Time', 'End Time', 'Duration', 'Leave Type', 'Leave Reason', 'Name', 'Inspector', 'DateMonthYear', 'C Duration', 'Start Month', 'End Month', 'Year'
                next_month.loc[i] = [ lv["Approval Org/Command"][i], lv["CityTime ID"][i], lv["Last Name"][i], lv["First Name"][i], lv["Title"][i], \
                                       lv["Start Time"][i], lv["End Time"][i], lv["Duration"][i], lv["Leave Type"][i], \
                                       lv["Leave Reason"][i], lv["Name"][i], lv["Inspector"][i], dateMonthYear, nm_duration, lv["Start Month"][i], lv["End Month"][i], lv["Year"][i]  ]
                    

                                                                         
print "Done"
